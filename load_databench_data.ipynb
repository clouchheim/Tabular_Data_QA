# %%
# libraries
from datasets import load_dataset
import pandas as pd

# %% [markdown]
# Load all of the QA data from the SemEval Task 8

# %%
# Load all QA pairs
all_qa = load_dataset("cardiffnlp/databench", name="qa", split="train")
# Out:
# ...
# Resolving data files:   0%|          | 0/65 [00:00<?, ?it/s]

# %%
# Load SemEval 2025 task 8 Question-Answer splits
semeval_train_qa = load_dataset("cardiffnlp/databench", name="semeval", split="train")
semeval_dev_qa = load_dataset("cardiffnlp/databench", name="semeval", split="dev")
# Out:
# ...
# Resolving data files:   0%|          | 0/49 [00:00<?, ?it/s]

# %% [markdown]
# Test to see form of data

# %%
# "001_Forbes", the id of the dataset
df_id = all_qa['dataset'][0]

# %%
# full dataset for 001_Forbes
forbes_df = pd.read_parquet(f"hf://datasets/cardiffnlp/databench/data/{df_id}/all.parquet")
forbes_df
# Out:
#       rank                personName   age  finalWorth               category  \
# 0        1                 Elon Musk  50.0      219000             Automotive
# 1        2                Jeff Bezos  58.0      171000             Technology
# 2        3  Bernard Arnault & family  73.0      158000       Fashion & Retail
# 3        4                Bill Gates  66.0      129000             Technology
# 4        5            Warren Buffett  91.0      118000  Finance & Investments
# ...    ...                       ...   ...         ...                    ...
# 2663  2578             Zhang Yuqiang  66.0        1000          Manufacturing
# 2664  2578                Zhou Ruxin  59.0        1000             Technology
# 2665  2578         Wen Zhou & family  57.0        1000          Manufacturing
# 2666  2578      Zhou Yifeng & family  43.0        1000                 Energy
# 2667  2578   Zhuang Kuilong & family  59.0        1000          Manufacturing
#
# ...

# %%
# qa contains the human-made set of questions, tagged by type and columns used, for the dataset
forbes_qa = pd.read_parquet(f"hf://datasets/cardiffnlp/databench/data/{df_id}/qa.parquet")

# %%
# filter to just 'number' and put all of those together from every dataframe 
forbes_qa
# Out:
#                                              question  \
# 0   Is the person with the highest net worth self-...
# 1     Does the youngest billionaire identify as male?
# 2   Is the city with the most billionaires in the ...
# 3   Is there a non-self-made billionaire in the to...
# 4   Does the oldest billionaire have a philanthrop...
# 5        What is the age of the youngest billionaire?
# 6   How many billionaires are there from the 'Tech...
# 7   What's the total worth of billionaires in the ...
# 8   How many billionaires have a philanthropy scor...
# 9   What's the rank of the wealthiest non-self-mad...
# 10  Which category does the richest billionaire be...
# 11  What's the country of origin of the oldest bil...
# 12  What's the gender of the billionaire with the ...
# 13  What's the source of wealth for the youngest b...
# 14  What is the title of the billionaire with the ...
# 15  List the top 3 countries with the most billion...
# ...

# %%
# sample dataset (20 colums)
sample_df = pd.read_parquet(f"hf://datasets/cardiffnlp/databench/data/{df_id}/sample.parquet")

# %%
type(sample_df)#[:10]
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # format the QA

# %%
# for each question in the QA
# !pip install table_bert
# Out:
# ERROR: Could not find a version that satisfies the requirement table_bert (from versions: none)
# ERROR: No matching distribution found for table_bert
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 3
#       1 # for each question in the QA
#       2 get_ipython().system('pip install table_bert')
# ----> 3 from table_bert import Table, Column
#
# ModuleNotFoundError: No module named 'table_bert'
