# %%
# libraries
from datasets import load_dataset
import pandas as pd

# %% [markdown]
# Load all of the QA data from the SemEval Task 8

# %%
# Load all QA pairs
all_qa = load_dataset("cardiffnlp/databench", name="qa", split="train")
# Out:
# Resolving data files:   0%|          | 0/65 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/65 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/65 [00:00<?, ?files/s]
# Generating train split:   0%|          | 0/1308 [00:00<?, ? examples/s]

# %%
# Load SemEval 2025 task 8 Question-Answer splits
semeval_train_qa = load_dataset("cardiffnlp/databench", name="semeval", split="train")
semeval_dev_qa = load_dataset("cardiffnlp/databench", name="semeval", split="dev")
# Out:
# Resolving data files:   0%|          | 0/65 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/49 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/65 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/49 [00:00<?, ?it/s]

# %% [markdown]
# Test to see form of data

# %%
# "001_Forbes", the id of the dataset
df_id = all_qa['dataset'][50]
df_id
# Out:
# '003_Love'

# %%
# full dataset for 001_Forbes
forbes_df = pd.read_parquet(f"hf://datasets/cardiffnlp/databench/data/{df_id}/all.parquet")
forbes_df
# Out:
#                  Submitted at  What is your age? 👶🏻👵🏻  \
# 0   2023-01-09 18:00:35+00:00                      51
# 1   2023-01-09 18:02:25+00:00                      28
# 2   2023-01-09 18:05:17+00:00                      45
# 3   2023-01-09 18:06:36+00:00                      29
# 4   2023-01-09 18:13:45+00:00                      27
# ..                        ...                     ...
# 368 2023-05-01 12:06:10+00:00                      21
# 369 2023-05-02 16:42:21+00:00                      33
# 370 2023-05-03 12:47:08+00:00                      34
# 371 2023-05-06 11:02:50+00:00                      23
# 372 2023-05-09 09:00:40+00:00                      36
#
#     What's your nationality? What is your civil status? 💍  \
# 0                        NaN                      Married
# 1                        NaN                       Single
# 2                        NaN                      Married
# 3                        NaN                       Single
# 4                        NaN            In a Relationship
# ..                       ...                          ...
# 368                   France                       Single
# 369                    Spain            In a Relationship
# 370                    Spain                       Single
# 371                  Germany            In a Relationship
# 372                    Spain                      Married
#
#     What's your sexual orientation? Do you have children? 🍼  \
# 0                               NaN                     Yes
# 1                               NaN                      No
# 2                               NaN                     Yes
# 3                               NaN                      No
# 4                               NaN                      No
# ..                              ...                     ...
# 368                    Heterosexual                      No
# 369                      Homosexual                      No
# 370                    Heterosexual                      No
# 371                        Bisexual                      No
# 372                    Heterosexual                      No
#
#     What is the maximum level of studies you have achieved? 🎓  \
# 0                                                  PhD
# 1                                               Master
# 2                                               Master
# 3                                               Master
# 4                                               Master
# ..                                                 ...
# 368                                     College Degree
# 369                                     College Degree
# 370                                             Master
# 371                                     College Degree
# 372                                             Master
#
#      Gross annual salary (in euros) 💸  What's your height? in cm 📏  \
# 0                            125000.0                          180
# 1                             90000.0                          186
# 2                             90000.0                          190
# 3                             55000.0                          164
# 4                             25000.0                          163
# ..                                ...                          ...
# 368                           20000.0                          187
# 369                          120000.0                          184
# 370                           72000.0                          174
# 371                           30000.0                          164
# 372                           50000.0                          175
#
#      What's your weight? in Kg ⚖️  ...  \
# 0                            82.0  ...
# 1                            83.0  ...
# 2                           107.0  ...
# 3                            62.0  ...
# 4                            55.0  ...
# ..                            ...  ...
# 368                          70.0  ...
# 369                          80.0  ...
# 370                          65.0  ...
# 371                          50.0  ...
# 372                          67.0  ...
#
#     Where have you met your sexual partners? (Neighbors)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 368                                              False
# 369                                              False
# 370                                              False
# 371                                               True
# 372                                              False
#
#     Where have you met your sexual partners? (in Church)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 368                                              False
# 369                                              False
# 370                                              False
# 371                                              False
# 372                                              False
#
#     Where have you met your sexual partners? (Other)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# ..                                               ...
# 368                                            False
# 369                                            False
# 370                                            False
# 371                                            False
# 372                                            False
#
#      How many people have you kissed? How many sexual partners have you had?  \
# 0                                   4                                      1
# 1                                  70                                     30
# 2                                   8                                      4
# 3                                   2                                      2
# 4                                  50                                     25
# ..                                ...                                    ...
# 368                                40                                      6
# 369                               220                                    200
# 370                                30                                     15
# 371                                25                                     15
# 372                                25                                     20
#
#     How many people have you considered as your boyfriend_girlfriend?  \
# 0                                                    2
# 1                                                    0
# 2                                                    3
# 3                                                    0
# 4                                                    7
# ..                                                 ...
# 368                                                  1
# 369                                                  7
# 370                                                  2
# 371                                                  5
# 372                                                  7
#
#     How many times per month did you practice sex lately?  Happiness scale  \
# 0                                                 25.0                   9
# 1                                                  4.0                   7
# 2                                                  3.0                  10
# 3                                                  2.0                   8
# 4                                                 10.0                   8
# ..                                                 ...                 ...
# 368                                                3.0                   9
# 369                                               10.0                   8
# 370                                                1.0                   5
# 371                                                5.0                   8
# 372                                                2.0                   8
#
#           What area of knowledge is closer to you?  \
# 0                      [Computer Science, Science]
# 1    [Enginering & Architecture, Computer Science]
# 2                               [Art & Humanities]
# 3             [Health, Business, Computer Science]
# 4                               [Art & Humanities]
# ..                                             ...
# 368                                     [Business]
# 369                                       [Health]
# 370                    [Enginering & Architecture]
# 371                   [Art & Humanities, Business]
# 372                    [Computer Science, Science]
#
#      If you are in a relationship, how long have you been with your partner?
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 368                                                2.4
# 369                                                0.5
# 370                                                0.3
# 371                                                0.5
# 372                                                NaN
#
# [373 rows x 35 columns]

# %%
# qa contains the human-made set of questions, tagged by type and columns used, for the dataset
forbes_qa = pd.read_parquet(f"hf://datasets/cardiffnlp/databench/data/{df_id}/qa.parquet")

# %%
# filter to just 'number' and put all of those together from every dataframe 
forbes_qa
# Out:
#                                              question  \
# 0     Is the average age of the respondents above 30?
# 1   Are there more single individuals than married...
# 2   Do the majority of respondents have a height g...
# 3              Is the most frequent hair color black?
# 4   How many unique nationalities are present in t...
# 5            What is the average gross annual salary?
# 6     How many respondents wear glasses all the time?
# 7           What's the median age of the respondents?
# 8   What is the most common level of studies achie...
# 9   Which body complexity has the least number of ...
# 10                What's the most frequent eye color?
# 11  Which sexual orientation has the highest repre...
# 12     List the top 3 most common areas of knowledge.
# 13  List the bottom 3 hair lengths in terms of fre...
# 14  Name the top 5 civil statuses represented in t...
# 15           What are the 4 least common hair colors?
# 16  What are the top 4 maximum gross annual salaries?
# 17  Name the bottom 3 values for the happiness scale.
# 18  What are the 5 highest ages present in the dat...
# 19  List the bottom 6 skin tone values based on fr...
#
#                                                answer            type  \
# 0                                                True         boolean
# 1                                                True         boolean
# 2                                                True         boolean
# 3                                               False         boolean
# 4                                                  13          number
# 5                                   56332.81720430108          number
# 6                                                  98          number
# 7                                                33.0          number
# 8                                              Master        category
# 9                                           Very thin        category
# 10                                              Brown        category
# 11                                       Heterosexual        category
# 12  ['[Computer Science]', '[Business]', '[Enginer...  list[category]
# 13                         ['Medium', 'Long', 'Bald']  list[category]
# 14  ['Single', 'Married', 'In a Relationship', 'In...  list[category]
# 15                  ['Red', 'Other', 'White', 'Blue']  list[category]
# 16           [500000.0, 360000.0, 300000.0, 300000.0]    list[number]
# 17                                          [2, 2, 2]    list[number]
# 18                               [65, 62, 60, 60, 59]    list[number]
# 19                                 [2, 1, 6, 0, 7, 8]    list[number]
#
#                                          columns_used        column_types  \
# 0                          ['What is your age? 👶🏻👵🏻']   ['number[uint8]']
# 1                    ['What is your civil status? 💍']        ['category']
# 2                       [What's your height? in cm 📏]   ['number[uint8]']
# 3                   ['What is your hair color? 👩🦰👱🏽']        ['category']
# 4                        [What's your nationality?"]"        ['category']
# 5                ['Gross annual salary (in euros) 💸']  ['number[UInt32]']
# 6                ['How often do you wear glasses? 👓']        ['category']
# 7                          ['What is your age? 👶🏻👵🏻']   ['number[uint8]']
# 8   ['What is the maximum level of studies you hav...        ['category']
# 9                ['What is your body complexity? 🏋️']        ['category']
# 10                     ['What is your eye color? 👁️']        ['category']
# 11                ['What's your sexual orientation?']        ['category']
# 12       ['What area of knowledge is closer to you?']  ['list[category]']
# 13                ['How long is your hair? 💇🏻♀️💇🏽♂️']        ['category']
# 14                   ['What is your civil status? 💍']        ['category']
# 15                  ['What is your hair color? 👩🦰👱🏽']        ['category']
# 16               ['Gross annual salary (in euros) 💸']  ['number[UInt32]']
# 17                                ['Happiness scale']   ['number[uint8]']
# 18                         ['What is your age? 👶🏻👵🏻']   ['number[uint8]']
# 19                        ['What is your skin tone?']   ['number[uint8]']
#
#                                         sample_answer   dataset
# 0                                                True  003_Love
# 1                                               False  003_Love
# 2                                                True  003_Love
# 3                                               False  003_Love
# 4                                                   1  003_Love
# 5                                             62710.0  003_Love
# 6                                                   5  003_Love
# 7                                                32.5  003_Love
# 8                                              Master  003_Love
# 9                                               Obese  003_Love
# 10                                              Brown  003_Love
# 11                                       Heterosexual  003_Love
# 12  ['[Computer Science]', '[Business]', '[Enginer...  003_Love
# 13                        ['Short', 'Medium', 'Long']  003_Love
# 14  ['Married', 'In a Relationship', 'In a Relatio...  003_Love
# 15                                 ['Brown', 'Black']  003_Love
# 16           [150000.0, 130000.0, 125000.0, 120000.0]  003_Love
# 17                                         [7, 10, 6]  003_Love
# 18                               [65, 60, 51, 50, 50]  003_Love
# 19                                 [3, 1, 6, 2, 7, 0]  003_Love

# %%
# sample dataset (20 colums)
sample_df = pd.read_parquet(f"hf://datasets/cardiffnlp/databench/data/{df_id}/sample.parquet")

# %%
sample_df
# Out:
#             Submitted at  What is your age? 👶🏻👵🏻 What's your nationality?  \
# 0   2023-04-23T06:33:05Z                      39                    Spain
# 1   2023-01-09T20:07:48Z                      29                     None
# 2   2023-01-09T18:32:25Z                      42                     None
# 3   2023-04-22T23:35:43Z                      31                    Spain
# 4   2023-01-09T22:55:14Z                      41                     None
# 5   2023-04-22T18:59:09Z                      33                    Spain
# 6   2023-01-10T10:54:21Z                      32                     None
# 7   2023-01-11T20:35:42Z                      25                     None
# 8   2023-04-22T22:16:16Z                      25                    Spain
# 9   2023-01-12T08:43:35Z                      23                     None
# 10  2023-04-22T18:52:53Z                      50                    Spain
# 11  2023-01-09T20:38:39Z                      65                     None
# 12  2023-01-14T10:54:16Z                      29                     None
# 13  2023-01-09T22:38:11Z                      34                     None
# 14  2023-01-14T19:39:44Z                      60                     None
# 15  2023-04-22T20:09:37Z                      50                    Spain
# 16  2023-01-09T18:00:35Z                      51                     None
# 17  2023-04-22T18:51:56Z                      30                    Spain
# 18  2023-04-23T10:13:20Z                      30                    Spain
# 19  2023-01-10T17:41:37Z                      28                     None
#
#     What is your civil status? 💍 What's your sexual orientation?  \
# 0                        Married                    Heterosexual
# 1                        Married                            None
# 2                        Married                            None
# 3              In a Relationship                    Heterosexual
# 4                        Married                            None
# 5              In a Relationship                    Heterosexual
# 6                         Single                            None
# 7   In a Relationship Cohabiting                            None
# 8              In a Relationship                    Heterosexual
# 9   In a Relationship Cohabiting                            None
# 10                      Divorced                    Heterosexual
# 11                       Married                            None
# 12             In a Relationship                            None
# 13                       Married                            None
# 14                       Married                            None
# 15                       Married                    Heterosexual
# 16                       Married                            None
# 17             In a Relationship                      Homosexual
# 18                       Married                    Heterosexual
# 19  In a Relationship Cohabiting                            None
#
#    Do you have children? 🍼  \
# 0                      Yes
# 1                       No
# 2                      Yes
# 3                       No
# 4                      Yes
# 5                       No
# 6                       No
# 7                       No
# 8                       No
# 9                       No
# 10                      No
# 11                     Yes
# 12                      No
# 13                     Yes
# 14                     Yes
# 15                     Yes
# 16                     Yes
# 17                      No
# 18                      No
# 19                      No
#
#    What is the maximum level of studies you have achieved? 🎓  \
# 0                                              Master
# 1                                              Master
# 2                                              Master
# 3                                      College Degree
# 4                                              Master
# 5                                   Primary Education
# 6                                              Master
# 7                                              Master
# 8                            Technical Education (FP)
# 9                                      College Degree
# 10                                     College Degree
# 11                                             Master
# 12                                             Master
# 13                                             Master
# 14                                                PhD
# 15                                             Master
# 16                                                PhD
# 17                                                PhD
# 18                                     College Degree
# 19                                             Master
#
#     Gross annual salary (in euros) 💸  What's your height? in cm 📏  \
# 0                           120000.0                          183
# 1                            82000.0                          174
# 2                            60000.0                          183
# 3                            54000.0                          185
# 4                            50000.0                          170
# 5                           130000.0                          168
# 6                           150000.0                          170
# 7                            38000.0                          177
# 8                            21000.0                          170
# 9                             7200.0                          176
# 10                           15000.0                          178
# 11                           50000.0                          168
# 12                           12000.0                          165
# 13                           40000.0                          183
# 14                           50000.0                          180
# 15                           70000.0                          170
# 16                          125000.0                          180
# 17                           40000.0                          172
# 18                          100000.0                          174
# 19                           40000.0                          174
#
#     What's your weight? in Kg ⚖️  ...  \
# 0                           74.0  ...
# 1                           75.0  ...
# 2                           73.0  ...
# 3                           85.0  ...
# 4                           71.0  ...
# 5                           68.0  ...
# 6                           65.0  ...
# 7                           78.0  ...
# 8                           65.0  ...
# 9                          105.0  ...
# 10                          72.0  ...
# 11                          82.0  ...
# 12                          83.0  ...
# 13                          68.0  ...
# 14                          81.0  ...
# 15                          85.0  ...
# 16                          82.0  ...
# 17                          65.0  ...
# 18                          80.0  ...
# 19                          71.0  ...
#
#    Where have you met your sexual partners? (Neighbors)  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# 5                                               False
# 6                                               False
# 7                                               False
# 8                                               False
# 9                                               False
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
# 15                                              False
# 16                                              False
# 17                                              False
# 18                                              False
# 19                                              False
#
#    Where have you met your sexual partners? (in Church)  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# 5                                               False
# 6                                               False
# 7                                               False
# 8                                               False
# 9                                               False
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
# 15                                              False
# 16                                              False
# 17                                              False
# 18                                              False
# 19                                              False
#
#    Where have you met your sexual partners? (Other)  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
# 5                                             False
# 6                                              True
# 7                                             False
# 8                                             False
# 9                                             False
# 10                                            False
# 11                                            False
# 12                                             True
# 13                                            False
# 14                                            False
# 15                                            False
# 16                                            False
# 17                                            False
# 18                                            False
# 19                                            False
#
#     How many people have you kissed? How many sexual partners have you had?  \
# 0                                 20                                      8
# 1                                  5                                      1
# 2                                 20                                     10
# 3                                  5                                      4
# 4                                 50                                     15
# 5                                 40                                     30
# 6                                  6                                      5
# 7                                  5                                      4
# 8                                 50                                      3
# 9                                  1                                      1
# 10                                25                                     16
# 11                                 1                                      1
# 12                                10                                      7
# 13                                 6                                      4
# 14                                10                                      4
# 15                                30                                      6
# 16                                 4                                      1
# 17                                40                                     24
# 18                                 3                                      1
# 19                                 9                                      3
#
#    How many people have you considered as your boyfriend_girlfriend?  \
# 0                                                   6
# 1                                                   1
# 2                                                   5
# 3                                                   2
# 4                                                   7
# 5                                                  10
# 6                                                   3
# 7                                                   3
# 8                                                   1
# 9                                                   1
# 10                                                  6
# 11                                                  1
# 12                                                  3
# 13                                                  1
# 14                                                  3
# 15                                                  6
# 16                                                  2
# 17                                                  4
# 18                                                  1
# 19                                                  2
#
#    How many times per month did you practice sex lately?  Happiness scale  \
# 0                                                 3.0                   8
# 1                                                 8.0                   9
# 2                                                 1.0                   7
# 3                                                20.0                   7
# 4                                                 4.0                   8
# 5                                                 2.0                   7
# 6                                                 6.0                   8
# 7                                                 2.0                   8
# 8                                                10.0                   8
# 9                                                12.0                  10
# 10                                                5.0                   6
# 11                                                1.0                   8
# 12                                                5.0                   8
# 13                                                4.0                   9
# 14                                                8.0                   8
# 15                                                3.0                   8
# 16                                               25.0                   9
# 17                                                6.0                   7
# 18                                                2.0                   9
# 19                                                4.0                   8
#
#          What area of knowledge is closer to you?  \
# 0                              [Computer Science]
# 1                             [Science, Business]
# 2                     [Enginering & Architecture]
# 3                       [Computer Science, Other]
# 4                          [Law & Social Science]
# 5                    [Business, Art & Humanities]
# 6   [Computer Science, Enginering & Architecture]
# 7                     [Computer Science, Science]
# 8            [Computer Science, Art & Humanities]
# 9                              [Computer Science]
# 10                                     [Business]
# 11                                     [Business]
# 12           [Computer Science, Art & Humanities]
# 13                    [Enginering & Architecture]
# 14                             [Art & Humanities]
# 15                             [Computer Science]
# 16                    [Computer Science, Science]
# 17                [Law & Social Science, Science]
# 18                             [Computer Science]
# 19                                     [Business]
#
#     If you are in a relationship, how long have you been with your partner?
# 0                                                13.0
# 1                                                12.0
# 2                                                 NaN
# 3                                                 2.0
# 4                                                14.0
# 5                                                 4.0
# 6                                                 NaN
# 7                                                 4.0
# 8                                                 6.0
# 9                                                 6.0
# 10                                                0.9
# 11                                               30.0
# 12                                                5.5
# 13                                               12.0
# 14                                               14.0
# 15                                               23.0
# 16                                                NaN
# 17                                                3.0
# 18                                               11.0
# 19                                                5.0
#
# [20 rows x 35 columns]

# %% [markdown]
# # format the QA

# %%
# for each question in the QA
# !pip install table_bert
# Out:
# ERROR: Could not find a version that satisfies the requirement table_bert (from versions: none)
# ERROR: No matching distribution found for table_bert
